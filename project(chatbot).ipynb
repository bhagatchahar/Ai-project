# %%
from nltk.chat.util import Chat, reflections
pairs = [

    [
        r"What is the Status of my order ?",
        ["pl",]
    ],
    [
        r"2",
        ["Enter your zip code",]
    ],
    [
        r"3",
        ["I'm doing good\nHow about You ?",]
    ],
    [
        r"4",
        ["Its alright","Its OK, never mind",]
    ],
    [
        r"5",
        ["Nice to hear that","Alright :)",]
    ],
    [
        r"6",
        ["Hello", "Hey there",]
    ],
    [
        r"(.*) age?",
        ["I'm a computer program dude\nSeriously you are asking me this?",]

    ],
    [
        r"what (.*) want ?",
        ["Make me an offer I can't refuse",]

    ],
    [
        r"(.*) created ?",
        ["Nagesh created me using Python's NLTK library ","top secret ;)",]
    ],
    [
        r"(.*) (location|city) ?",
        ['Chennai, Tamil Nadu',]
    ],
    [
        r"how is weather in (.*)?",
        ["Weather in %1 is awesome like always","Too hot man here in %1","Too cold man here in %1","Never even heard about %1"]
    ],
    [
        r"i work in (.*)?",
        ["%1 is an Amazing company, I have heard about it. But they are in huge loss these days.",]
    ],

    [
        r"(.)raining in (.)",
        ["No rain since last week here in %2","Damn its raining too much here in %2"]
    ],
    [
        r"how (.) health(.)",
        ["I'm a computer program, so I'm always healthy ",]
    ],
    [
        r"(.*) (sports|game) ?",
        ["I'm a very big fan of Football",]
    ],
    [
        r"who (.*) sportsperson ?",
        ["Messy","Ronaldo","Roony"]
    ],
    [
        r"who (.*) (moviestar|actor)?",
        ["Brad Pitt"]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :) ","It was nice talking to you. See you soon :)"]
    ],
]

def chatty():
    print("Hi, I'm Lucy, the logistic bot.Thanks for chatting with me! I'm here to help with things like tracing a package,status of your order,delivery booking and delivery-related inquiries ;)\nPlease type lowercase English language to start a conversation. Type quit to leave ")
    x=input("Enter  your zip code:")
    print("Whatever you want to know mentioned in the list, :\n  1->Issue related to order  \n  2-> Shipment tracking \n  3-> Delivery-related inquiries \n  4-> Transection related inquiries \n  5-> Return product \n  6-> Defective product ")
    chat = Chat(pairs, reflections)
    chat.converse()

if _name_ == "_main_":
    chatty()

r.mainloop()
